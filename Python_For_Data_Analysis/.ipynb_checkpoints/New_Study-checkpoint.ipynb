# %%
import pandas as pd 
import numpy as np
import sys

# %%
path = 'C:/python/train.csv'

# %%
sys.stdin.encoding
# Out:
# 'cp949'

# %%
sys.stdout.encoding
# Out:
# 'UTF-8'

# %%
t = pd.read_csv(path)

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.value_counts(t['Pclass'])
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
t['Pclass'] = t['Pclass'].astype(str)

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null object
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.6+ KB

# %%
t.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000   80.000000    8.000000    6.000000  512.329200

# %%
pd.value_counts(t['Embarked'])
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
t.fillna(0 , inplace = True)

# %%
{ 'Embarked' : 'S', 'Fare' : 4, }
# Out:
# {'Embarked': 'S', 'Fare': 4}

# %%
t
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# 5              6         0      3
# 6              7         0      1
# 7              8         0      3
# 8              9         1      3
# 9             10         1      2
# 10            11         1      3
# 11            12         1      1
# 12            13         0      3
# 13            14         0      3
# 14            15         0      3
# 15            16         1      2
# 16            17         0      3
# 17            18         1      2
# 18            19         0      3
# 19            20         1      3
# 20            21         0      2
# 21            22         1      2
# 22            23         1      3
# 23            24         1      1
# 24            25         0      3
# 25            26         1      3
# ...

# %%
len(t['Name'].unique())
# Out:
# 891

# %%
len(t)
# Out:
# 891

# %%
t
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# 5              6         0      3
# 6              7         0      1
# 7              8         0      3
# 8              9         1      3
# 9             10         1      2
# 10            11         1      3
# 11            12         1      1
# 12            13         0      3
# 13            14         0      3
# 14            15         0      3
# 15            16         1      2
# 16            17         0      3
# 17            18         1      2
# 18            19         0      3
# 19            20         1      3
# 20            21         0      2
# 21            22         1      2
# 22            23         1      3
# 23            24         1      1
# 24            25         0      3
# 25            26         1      3
# ...

# %%
t.drop(['Name'], axis = 1, inplace = True)

# %%
t.head()
# Out:
#    PassengerId  Survived Pclass     Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0      3    male  22.0      1      0         A/5 21171
# 1            2         1      1  female  38.0      1      0          PC 17599
# 2            3         1      3  female  26.0      0      0  STON/O2. 3101282
# 3            4         1      1  female  35.0      1      0            113803
# 4            5         0      3    male  35.0      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500     0        S
# 1  71.2833   C85        C
# 2   7.9250     0        S
# 3  53.1000  C123        S
# 4   8.0500     0        S

# %%
len(t['PassengerId'].unique())
# Out:
# 891

# %%
t.drop(['PassengerId'], axis = 1, inplace = True)

# %%
t.head()
# Out:
#    Survived Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0      3    male  22.0      1      0         A/5 21171   7.2500
# 1         1      1  female  38.0      1      0          PC 17599  71.2833
# 2         1      3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1      1  female  35.0      1      0            113803  53.1000
# 4         0      3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0     0        S
# 1   C85        C
# 2     0        S
# 3  C123        S
# 4     0        S

# %%
t.dropna(how = 'any', axis = 0)
# Out:
#      Survived Pclass     Sex   Age  SibSp  Parch            Ticket      Fare  \
# 0           0      3    male  22.0      1      0         A/5 21171    7.2500
# 1           1      1  female  38.0      1      0          PC 17599   71.2833
# 2           1      3  female  26.0      0      0  STON/O2. 3101282    7.9250
# 3           1      1  female  35.0      1      0            113803   53.1000
# 4           0      3    male  35.0      0      0            373450    8.0500
# 5           0      3    male   0.0      0      0            330877    8.4583
# 6           0      1    male  54.0      0      0             17463   51.8625
# 7           0      3    male   2.0      3      1            349909   21.0750
# 8           1      3  female  27.0      0      2            347742   11.1333
# 9           1      2  female  14.0      1      0            237736   30.0708
# 10          1      3  female   4.0      1      1           PP 9549   16.7000
# ...

# %%
t['Fare']
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
#          ...
# 861     11.5000
# 862     25.9292
# 863     69.5500
# 864     13.0000
# 865     13.0000
# 866     13.8583
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 871     52.5542
# 872      5.0000
# 873      9.0000
# 874     24.0000
# 875      7.2250
# 876      9.8458
# 877      7.8958
# 878      7.8958
# 879     83.1583
# 880     26.0000
# 881      7.8958
# 882     10.5167
# 883     10.5000
# 884      7.0500
# ...

# %%
t['Fare_10'] = t['Fare'].apply(lambda x : x * 10)

# %%
t['Ticket_3'] = t['Ticket'].apply(lambda x : x[:3])

# %%
t.head()
# Out:
#    Survived Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0      3    male  22.0      1      0         A/5 21171   7.2500
# 1         1      1  female  38.0      1      0          PC 17599  71.2833
# 2         1      3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1      1  female  35.0      1      0            113803  53.1000
# 4         0      3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked  Fare_10 Ticket_3
# 0     0        S   72.500      A/5
# 1   C85        C  712.833      PC
# 2     0        S   79.250      STO
# 3  C123        S  531.000      113
# 4     0        S   80.500      373

# %%
l = t.groupby('Sex').mean()

# %%
t.unstack()
# Out:
# Survived  0        0
#           1        1
#           2        1
#           3        1
#           4        0
#           5        0
#           6        0
#           7        0
#           8        1
#           9        1
#           10       1
#           11       1
#           12       0
#           13       0
#           14       0
#           15       1
#           16       0
#           17       1
#           18       0
#           19       1
#           20       0
#           21       1
#           22       1
#           23       1
#           24       0
#           25       1
#           26       0
#           27       0
#           28       1
#           29       0
#                 ...
# Ticket_3  861    281
#           862    174
#           863    CA.
#           864    233
#           865    236
#           866    SC/
#           867    PC
#           868    345
#           869    347
#           870    349
#           871    117
#           872    695
# ...

# %%
t['Survived'] = t['Survived'].astype(str)

# %%
t.head()
# Out:
#   Survived Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0        0      3    male  22.0      1      0         A/5 21171   7.2500
# 1        1      1  female  38.0      1      0          PC 17599  71.2833
# 2        1      3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3        1      1  female  35.0      1      0            113803  53.1000
# 4        0      3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked  Fare_10 Ticket_3 Survivied
# 0     0        S   72.500      A/5         0
# 1   C85        C  712.833      PC          1
# 2     0        S   79.250      STO         1
# 3  C123        S  531.000      113         1
# 4     0        S   80.500      373         0

# %%
t.pivot('Survived','Pclass')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-0badc8b14fdf> in <module>()
# ----> 1 t.pivot('Survived','Pclass')
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    4380         """
#    4381         from pandas.core.reshape.reshape import pivot
# -> 4382         return pivot(self, index=index, columns=columns, values=values)
#    4383
#    4384     _shared_docs['pivot_table'] = """
#
# c:\program files\python36\lib\site-packages\pandas\core\reshape\reshape.py in pivot(self, index, columns, values)
#     379         append = index is None
#     380         indexed = self.set_index(cols, append=append)
# --> 381         return indexed.unstack(columns)
#     382     else:
#     383         if index is None:
#
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# Survived     891 non-null object
# Pclass       891 non-null object
# Sex          891 non-null object
# Age          891 non-null float64
# SibSp        891 non-null int64
# Parch        891 non-null int64
# Ticket       891 non-null object
# Fare         891 non-null float64
# Cabin        891 non-null object
# Embarked     891 non-null object
# Fare_10      891 non-null float64
# Ticket_3     891 non-null object
# Survivied    891 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 90.6+ KB

# %%
t.drop('Survivied', axis = 1, inplace = True)

# %%
pd.get_dummies(t).columns
# Out:
# Index(['Age', 'SibSp', 'Parch', 'Fare', 'Fare_10', 'Survived_0', 'Survived_1',
#        'Pclass_1', 'Pclass_2', 'Pclass_3',
#        ...
#        'Ticket_3_SC/', 'Ticket_3_SCO', 'Ticket_3_SO/', 'Ticket_3_SOT',
#        'Ticket_3_STO', 'Ticket_3_SW/', 'Ticket_3_W./', 'Ticket_3_W.E',
#        'Ticket_3_W/C', 'Ticket_3_WE/'],
#       dtype='object', length=999)
