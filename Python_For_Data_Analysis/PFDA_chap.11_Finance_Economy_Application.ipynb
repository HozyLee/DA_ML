# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 11 금융 경제 데어 애플리케이션
# #### 금융 분야에서 파이썬 사용률 증가
# #### 장점
# #### interpreter 형식
# #### 관련 라이브러리 다양
# #### 시스템 구축의 시간 절약 : 생산성 up
#
# #### 초점 - 크로스섹션 : 시간 상 고정된 위치에 존재하는 데이터

# %% [markdown]
# ## 11.1 데이터 준비

# %% [markdown]
# ## 11.1.1 시계열과 크로스 섹션 정렬
# #### 금융 데이터 : 데이터 정렬에 많은 시간 소요
# #### 문제의 원인
# #### 1. 서로 다른 데이터의 시계열 인덱스의 불일치
# #### 2. dataframe 객체의 행이나 열의 라벨 불일치
#
# #### 여기서 pandas의 장점이 나타난다!!!!!
# #### 산술 연산을 통해 자동적으로 데이터를 정렬하는 방식

# %%
import pickle

# %%
pd.read_json
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-cb8dd20f2e67> in <module>()
# ----> 1 pd.read_json(pydata-book/examples/example.json)
#
# NameError: name 'pydata' is not defined

# %%
pd.read_pickle('C:\\python\\DATA_SET\\yahoo_price.pkl')
# Out:
#                   AAPL        GOOG         IBM       MSFT
# Date
# 2010-01-04   27.990226  313.062468  113.304536  25.884104
# 2010-01-05   28.038618  311.683844  111.935822  25.892466
# 2010-01-06   27.592626  303.826685  111.208683  25.733566
# 2010-01-07   27.541619  296.753749  110.823732  25.465944
# 2010-01-08   27.724725  300.709808  111.935822  25.641571
# 2010-01-11   27.480148  300.255255  110.763844  25.315406
# 2010-01-12   27.167562  294.945572  111.644958  25.148142
# 2010-01-13   27.550775  293.252243  111.405433  25.382312
# 2010-01-14   27.391211  294.630868  113.184773  25.892466
# 2010-01-15   26.933449  289.710772  112.731385  25.808835
# 2010-01-19   28.124939  293.516976  114.750251  26.009552
# 2010-01-20   27.692027  289.915587  111.422546  25.583028
# 2010-01-21   27.213337  291.199286  110.353231  25.097963
# 2010-01-22   25.863592  274.730736  107.359151  24.219826
# 2010-01-25   26.559391  269.730740  107.889534  24.520902
# ...

# %%
f = open('C:\\python\\DATA_SET\\yahoo_price.pkl')

# %%
x = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-b58f0603f991> in <module>()
# ----> 1 x = pickle.load(f)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x80 in position 0: illegal multibyte sequence

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: Windows
#  볼륨 일련 번호: E68C-5DCC
#
#  C:\Users\HojaeLee\Python_Study 디렉터리
#
# 2018-04-03  오후 02:57    <DIR>          .
# 2018-04-03  오후 02:57    <DIR>          ..
# 2018-04-03  오후 02:18    <DIR>          .ipynb_checkpoints
# 2018-03-22  오후 02:52             3,230 APMonitor.ipynb
# 2018-02-12  오후 11:44             9,689 fig2.pdf
# 2018-02-12  오전 12:39             9,641 fig2n.pdf
# 2018-02-12  오전 12:33             1,197 figpath.pdf
# 2018-02-12  오전 12:33               618 figpath.svg
# 2018-03-26  오후 12:11            66,349 file that convert to csv.csv
# 2018-03-26  오후 09:55           182,218 HJ_proj_Bitcoin.ipynb
# 2018-03-07  오후 07:02         1,763,342 HJ_proj_WeatherDA.ipynb
# 2018-04-03  오전 11:49           480,417 PFDA_chap.10_Time_Series.ipynb
# 2018-04-03  오후 02:57            12,400 PFDA_chap.11_Finance_Economy_Application.ipynb
# 2018-03-23  오후 04:12            54,214 PFDA_chap.4_Numpy.ipynb
# 2018-03-26  오후 12:10           149,844 PFDA_chap.5_Pandas.ipynb
# ...

# %%
pickle.load(open('C:\\python\\DATA_SET\\yahoo_price.pkl'))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-91717d4c29b7> in <module>()
# ----> 1 pickle.load(open('C:\\python\\DATA_SET\\yahoo_price.pkl'))
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x80 in position 0: illegal multibyte sequence

# %%
open('C:\\python\\DATA_SET\\yahoo_price.pkl')
# Out:
# <_io.TextIOWrapper name='C:\\python\\DATA_SET\\yahoo_price.pkl' mode='r' encoding='cp949'>

# %%
pd.read_table(open('C:\\python\\DATA_SET\\yahoo_price.pkl'))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-a62817d6dfe3> in <module>()
# ----> 1 pd.read_table(open('C:\\python\\DATA_SET\\yahoo_price.pkl'))
#
# ...
